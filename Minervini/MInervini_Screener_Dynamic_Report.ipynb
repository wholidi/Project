# %%
# Finnhub Setup
import requests
import pandas as pd
import datetime
import time

FINNHUB_API_KEY = "API key"  # Replace with your actual key

def get_finnhub_data(symbol, resolution="D", from_days=365):
    end_time = int(time.time())
    start_time = int(end_time - from_days * 86400)

    url = "https://finnhub.io/api/v1/stock/candle"
    params = {
        "symbol": symbol,
        "resolution": resolution,
        "from": start_time,
        "to": end_time,
        "token": FINNHUB_API_KEY
    }

    response = requests.get(url, params=params)
    data = response.json()

    if data.get("s") != "ok":
        print(f"Error fetching data for {symbol}: {data}")
        return pd.DataFrame()

    df = pd.DataFrame({
        "timestamp": pd.to_datetime(data["t"], unit="s"),
        "open": data["o"],
        "high": data["h"],
        "low": data["l"],
        "close": data["c"],
        "volume": data["v"]
    }).set_index("timestamp")

    return df

# %%
# ✅ Get tickers for all S&P 500 stocks from Wikipedia
import requests
import pandas as pd

def tickers_sp500():
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    html = requests.get(url).text
    df = pd.read_html(html, header=0)[0]
    tickers = df['Symbol'].dropna().tolist()
    return tickers

tickers = tickers_sp500()
print(f"✅ Loaded {len(tickers)} S&P 500 tickers")
# Out:
# C:\Users\930140\AppData\Local\Temp\1/ipykernel_32196/397156897.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(html, header=0)[0]
# ✅ Loaded 503 S&P 500 tickers

# %%
# Index return using Finnhub (SPY as proxy for S&P 500)
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()

index_symbol = "SPY"
index_df = get_finnhub_data(index_symbol)
index_df = index_df.loc[start_date:end_date]
index_df["close"] = index_df["close"].astype(float)
index_df["Percent Change"] = index_df["close"].pct_change()
index_return = (index_df["Percent Change"] + 1).cumprod().iloc[-1]
print(f"S&P 500 proxy return (SPY): {index_return:.2f}x")
# Out:
# S&P 500 proxy return (SPY): 1.11x

# %%
# RS Rating scanner 
returns_multiples = []
failed_tickers = []
successful_tickers = []

for symbol in tickers:
    try:
        df = get_finnhub_data(symbol)
        if df.empty or "close" not in df.columns:
            print(f"⚠️ Skipping {symbol}: No data or bad format")
            failed_tickers.append(symbol)
            returns_multiples.append(0)
            continue

        df["close"] = df["close"].astype(float)
        df = df.loc[start_date:end_date]
        df["Percent Change"] = df["close"].pct_change()
        stock_return = (df["Percent Change"] + 1).cumprod().iloc[-1]
        rs_score = stock_return / index_return
        returns_multiples.append(rs_score)
        successful_tickers.append(symbol)
        print(f"✅ {symbol} processed successfully – RS Score: {rs_score:.2f}")
        
    except Exception as e:
        print(f"❌ Error for {symbol}: {e}")
        failed_tickers.append(symbol)
        returns_multiples.append(0)

# ✅ Save failed tickers to a text file
with open("failed_tickers.txt", "w") as f:
    for ticker in failed_tickers:
        f.write(f"{ticker}\n")

# ✅ Save successful tickers too (optional)
with open("successful_tickers.txt", "w") as f:
    for ticker in successful_tickers:
        f.write(f"{ticker}\n")

print(f"\n📄 {len(successful_tickers)} successfull logged to successfull_tickers.txt")
print(f"📄 {len(failed_tickers)} failed tickers logged to failed_tickers.txt")
# Out:
# ✅ MMM processed successfully – RS Score: 1.27
# ✅ AOS processed successfully – RS Score: 0.72
# ✅ ABT processed successfully – RS Score: 1.10
# ✅ ABBV processed successfully – RS Score: 0.97
# ✅ ACN processed successfully – RS Score: 0.94
# ✅ ADBE processed successfully – RS Score: 0.74
# ✅ AMD processed successfully – RS Score: 0.65
# ✅ AES processed successfully – RS Score: 0.53
# ✅ AFL processed successfully – RS Score: 1.07
# ✅ A processed successfully – RS Score: 0.65
# ✅ APD processed successfully – RS Score: 0.95
# ✅ ABNB processed successfully – RS Score: 0.84
# ✅ AKAM processed successfully – RS Score: 0.72
# ✅ ALB processed successfully – RS Score: 0.43
# ✅ ARE processed successfully – RS Score: 0.51
# ✅ ALGN processed successfully – RS Score: 0.62
# ✅ ALLE processed successfully – RS Score: 1.01
# ✅ LNT processed successfully – RS Score: 1.05
# ✅ ALL processed successfully – RS Score: 1.07
# ✅ GOOGL processed successfully – RS Score: 0.85
# ✅ GOOG processed successfully – RS Score: 0.86
# ✅ MO processed successfully – RS Score: 1.10
# ✅ AMZN processed successfully – RS Score: 1.03
# ✅ AMCR processed successfully – RS Score: 0.80
# ✅ AEE processed successfully – RS Score: 1.14
# ✅ AEP processed successfully – RS Score: 0.96
# ✅ AXP processed successfully – RS Score: 1.12
# ✅ AIG processed successfully – RS Score: 0.94
# ✅ AMT processed successfully – RS Score: 0.94
# ✅ AWK processed successfully – RS Score: 0.90
# ✅ AMP processed successfully – RS Score: 1.08
# ✅ AME processed successfully – RS Score: 0.96
# ✅ AMGN processed successfully – RS Score: 0.75
# ✅ APH processed successfully – RS Score: 1.17
# ✅ ADI processed successfully – RS Score: 0.95
# ✅ ANSS processed successfully – RS Score: 0.96
# ✅ AON processed successfully – RS Score: 1.09
# ✅ APA processed successfully – RS Score: 0.54
# ✅ APO processed successfully – RS Score: 1.15
# ✅ AAPL processed successfully – RS Score: 1.01
# ✅ AMAT processed successfully – RS Score: 0.73
# ✅ APTV processed successfully – RS Score: 0.76
# ✅ ACGL processed successfully – RS Score: 0.83
# ✅ ADM processed successfully – RS Score: 0.72
# ✅ ANET processed successfully – RS Score: 1.10
# ✅ AJG processed successfully – RS Score: 1.16
# ✅ AIZ processed successfully – RS Score: 1.01
# ✅ T processed successfully – RS Score: 1.38
# ✅ ATO processed successfully – RS Score: 1.16
# ✅ ADSK processed successfully – RS Score: 1.21
# ✅ ADP processed successfully – RS Score: 1.11
# ✅ AZO processed successfully – RS Score: 1.13
# ✅ AVB processed successfully – RS Score: 0.92
# ✅ AVY processed successfully – RS Score: 0.72
# ✅ AXON processed successfully – RS Score: 2.26
# ✅ BKR processed successfully – RS Score: 1.03
# ✅ BALL processed successfully – RS Score: 0.68
# ✅ BAC processed successfully – RS Score: 1.03
# ✅ BAX processed successfully – RS Score: 0.78
# ✅ BDX processed successfully – RS Score: 0.65
# ✅ BRK.B processed successfully – RS Score: 1.10
# ✅ BBY processed successfully – RS Score: 0.90
# ✅ TECH processed successfully – RS Score: 0.52
# ✅ BIIB processed successfully – RS Score: 0.47
# ✅ BLK processed successfully – RS Score: 1.08
# ✅ BX processed successfully – RS Score: 1.04
# ✅ BK processed successfully – RS Score: 1.35
# ✅ BA processed successfully – RS Score: 1.01
# ✅ BKNG processed successfully – RS Score: 1.26
# ✅ BSX processed successfully – RS Score: 1.24
# ✅ BMY processed successfully – RS Score: 0.90
# ✅ AVGO processed successfully – RS Score: 1.48
# ✅ BR processed successfully – RS Score: 1.05
# ✅ BRO processed successfully – RS Score: 1.09
# ✅ BF.B processed successfully – RS Score: 0.64
# ✅ BLDR processed successfully – RS Score: 0.65
# ✅ BG processed successfully – RS Score: 0.71
# ✅ BXP processed successfully – RS Score: 0.93
# ✅ CHRW processed successfully – RS Score: 1.06
# ✅ CDNS processed successfully – RS Score: 0.99
# ✅ CZR processed successfully – RS Score: 0.78
# ✅ CPT processed successfully – RS Score: 0.98
# ✅ CPB processed successfully – RS Score: 0.66
# ✅ COF processed successfully – RS Score: 1.26
# ✅ CAH processed successfully – RS Score: 1.35
# ✅ KMX processed successfully – RS Score: 0.84
# ✅ CCL processed successfully – RS Score: 1.39
# ✅ CARR processed successfully – RS Score: 1.02
# ✅ CAT processed successfully – RS Score: 0.90
# ✅ CBOE processed successfully – RS Score: 1.06
# ✅ CBRE processed successfully – RS Score: 1.26
# ✅ CDW processed successfully – RS Score: 0.76
# ✅ COR processed successfully – RS Score: 1.13
# ✅ CNC processed successfully – RS Score: 0.69
# ✅ CNP processed successfully – RS Score: 1.10
# ✅ CF processed successfully – RS Score: 1.00
# ✅ CRL processed successfully – RS Score: 0.56
# ✅ SCHW processed successfully – RS Score: 1.00
# ✅ CHTR processed successfully – RS Score: 1.34
# ✅ CVX processed successfully – RS Score: 0.79
# ✅ CMG processed successfully – RS Score: 0.75
# ✅ CB processed successfully – RS Score: 0.96
# ✅ CHD processed successfully – RS Score: 0.79
# ✅ CI processed successfully – RS Score: 0.80
# ✅ CINF processed successfully – RS Score: 1.11
# ✅ CTAS processed successfully – RS Score: 1.11
# ✅ CSCO processed successfully – RS Score: 1.14
# ✅ C processed successfully – RS Score: 1.06
# ✅ CFG processed successfully – RS Score: 1.02
# ✅ CLX processed successfully – RS Score: 0.88
# ✅ CME processed successfully – RS Score: 1.13
# ✅ CMS processed successfully – RS Score: 0.98
# ✅ KO processed successfully – RS Score: 0.98
# ✅ CTSH processed successfully – RS Score: 1.03
# ✅ CL processed successfully – RS Score: 0.83
# ✅ CMCSA processed successfully – RS Score: 0.79
# ✅ CAG processed successfully – RS Score: 0.65
# ✅ COP processed successfully – RS Score: 0.70
# ✅ ED processed successfully – RS Score: 0.92
# ✅ STZ processed successfully – RS Score: 0.66
# ✅ CEG processed successfully – RS Score: 1.20
# ✅ COO processed successfully – RS Score: 0.74
# ✅ CPRT processed successfully – RS Score: 1.03
# ✅ GLW processed successfully – RS Score: 1.20
# ✅ CPAY processed successfully – RS Score: 1.12
# ✅ CTVA processed successfully – RS Score: 1.09
# ✅ CSGP processed successfully – RS Score: 0.77
# ✅ COST processed successfully – RS Score: 1.12
# ✅ CTRA processed successfully – RS Score: 0.80
# ✅ CRWD processed successfully – RS Score: 1.16
# ✅ CCI processed successfully – RS Score: 0.85
# ✅ CSX processed successfully – RS Score: 0.82
# ✅ CMI processed successfully – RS Score: 1.04
# ✅ CVS processed successfully – RS Score: 0.94
# ✅ DHR processed successfully – RS Score: 0.64
# ✅ DRI processed successfully – RS Score: 1.23
# ✅ DVA processed successfully – RS Score: 0.92
# ✅ DAY processed successfully – RS Score: 0.85
# Error fetching data for DECK: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DECK: No data or bad format
# Error fetching data for DE: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DE: No data or bad format
# Error fetching data for DELL: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DELL: No data or bad format
# Error fetching data for DAL: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DAL: No data or bad format
# Error fetching data for DVN: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DVN: No data or bad format
# Error fetching data for DXCM: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DXCM: No data or bad format
# Error fetching data for FANG: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping FANG: No data or bad format
# Error fetching data for DLR: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DLR: No data or bad format
# Error fetching data for DFS: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DFS: No data or bad format
# Error fetching data for DG: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DG: No data or bad format
# Error fetching data for DLTR: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DLTR: No data or bad format
# Error fetching data for D: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping D: No data or bad format
# Error fetching data for DPZ: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DPZ: No data or bad format
# Error fetching data for DASH: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DASH: No data or bad format
# Error fetching data for DOV: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DOV: No data or bad format
# Error fetching data for DOW: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DOW: No data or bad format
# Error fetching data for DHI: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DHI: No data or bad format
# Error fetching data for DTE: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DTE: No data or bad format
# Error fetching data for DUK: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DUK: No data or bad format
# Error fetching data for DD: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping DD: No data or bad format
# Error fetching data for EMN: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EMN: No data or bad format
# Error fetching data for ETN: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping ETN: No data or bad format
# Error fetching data for EBAY: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EBAY: No data or bad format
# Error fetching data for ECL: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping ECL: No data or bad format
# Error fetching data for EIX: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EIX: No data or bad format
# Error fetching data for EW: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EW: No data or bad format
# Error fetching data for EA: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EA: No data or bad format
# Error fetching data for ELV: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping ELV: No data or bad format
# Error fetching data for EMR: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EMR: No data or bad format
# Error fetching data for ENPH: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping ENPH: No data or bad format
# Error fetching data for ETR: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping ETR: No data or bad format
# Error fetching data for EOG: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EOG: No data or bad format
# Error fetching data for EPAM: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EPAM: No data or bad format
# Error fetching data for EQT: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EQT: No data or bad format
# Error fetching data for EFX: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EFX: No data or bad format
# Error fetching data for EQIX: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EQIX: No data or bad format
# Error fetching data for EQR: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EQR: No data or bad format
# Error fetching data for ERIE: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping ERIE: No data or bad format
# Error fetching data for ESS: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping ESS: No data or bad format
# Error fetching data for EL: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EL: No data or bad format
# Error fetching data for EG: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EG: No data or bad format
# Error fetching data for EVRG: {'error': 'API limit reached. Please try again later. Remaining Limit: 0'}
# ⚠️ Skipping EVRG: No data or bad format
# ✅ ES processed successfully – RS Score: 0.90
# ✅ EXC processed successfully – RS Score: 0.98
# ✅ EXE processed successfully – RS Score: 1.22
# ✅ EXPE processed successfully – RS Score: 1.34
# ✅ EXPD processed successfully – RS Score: 0.87
# ✅ EXR processed successfully – RS Score: 0.87
# ✅ XOM processed successfully – RS Score: 0.83
# ✅ FFIV processed successfully – RS Score: 1.46
# ✅ FDS processed successfully – RS Score: 0.93
# ✅ FICO processed successfully – RS Score: 1.36
# ✅ FAST processed successfully – RS Score: 1.08
# ✅ FRT processed successfully – RS Score: 0.84
# ✅ FDX processed successfully – RS Score: 0.81
# ✅ FIS processed successfully – RS Score: 0.91
# ✅ FITB processed successfully – RS Score: 0.92
# ✅ FSLR processed successfully – RS Score: 0.89
# ✅ FE processed successfully – RS Score: 0.92
# ✅ FI processed successfully – RS Score: 1.12
# ✅ F processed successfully – RS Score: 0.77
# ✅ FTNT processed successfully – RS Score: 1.52
# ✅ FTV processed successfully – RS Score: 0.85
# ✅ FOXA processed successfully – RS Score: 1.50
# ✅ FOX processed successfully – RS Score: 1.50
# ✅ BEN processed successfully – RS Score: 0.82
# ✅ FCX processed successfully – RS Score: 0.68
# ✅ GRMN processed successfully – RS Score: 1.06
# ✅ IT processed successfully – RS Score: 0.90
# ✅ GE processed successfully – RS Score: 1.25
# ✅ GEHC processed successfully – RS Score: 0.81
# ✅ GEV processed successfully – RS Score: 2.34
# ✅ GEN processed successfully – RS Score: 1.01
# ✅ GNRC processed successfully – RS Score: 0.81
# ✅ GD processed successfully – RS Score: 0.82
# ✅ GIS processed successfully – RS Score: 0.67
# ✅ GM processed successfully – RS Score: 0.99
# ✅ GPC processed successfully – RS Score: 0.73
# ✅ GILD processed successfully – RS Score: 1.30
# ✅ GPN processed successfully – RS Score: 0.68
# ✅ GL processed successfully – RS Score: 1.28
# ✅ GDDY processed successfully – RS Score: 1.25
# ✅ GS processed successfully – RS Score: 1.18
# ✅ HAL processed successfully – RS Score: 0.51
# ✅ HIG processed successfully – RS Score: 1.11
# ✅ HAS processed successfully – RS Score: 0.99
# ✅ HCA processed successfully – RS Score: 1.02
# ✅ DOC processed successfully – RS Score: 0.76
# ✅ HSIC processed successfully – RS Score: 0.85
# ✅ HSY processed successfully – RS Score: 0.70
# ✅ HES processed successfully – RS Score: 0.78
# ✅ HPE processed successfully – RS Score: 0.90
# ✅ HLT processed successfully – RS Score: 1.11
# ✅ HOLX processed successfully – RS Score: 0.66
# ✅ HD processed successfully – RS Score: 0.98
# ✅ HON processed successfully – RS Score: 0.95
# ✅ HRL processed successfully – RS Score: 0.73
# ✅ HST processed successfully – RS Score: 0.74
# ✅ HWM processed successfully – RS Score: 1.74
# ✅ HPQ processed successfully – RS Score: 0.83
# ✅ HUBB processed successfully – RS Score: 0.89
# ✅ HUM processed successfully – RS Score: 0.58
# ✅ HBAN processed successfully – RS Score: 1.02
# ✅ HII processed successfully – RS Score: 0.78
# ✅ IBM processed successfully – RS Score: 1.37
# ✅ IEX processed successfully – RS Score: 0.76
# ✅ IDXX processed successfully – RS Score: 0.85
# ✅ ITW processed successfully – RS Score: 0.88
# ✅ INCY processed successfully – RS Score: 0.97
# ✅ IR processed successfully – RS Score: 0.82
# ✅ PODD processed successfully – RS Score: 1.56
# ✅ INTC processed successfully – RS Score: 0.60
# ✅ ICE processed successfully – RS Score: 1.13
# ✅ IFF processed successfully – RS Score: 0.69
# ✅ IP processed successfully – RS Score: 1.12
# ✅ IPG processed successfully – RS Score: 0.71
# ✅ INTU processed successfully – RS Score: 0.90
# ✅ ISRG processed successfully – RS Score: 1.28
# ✅ IVZ processed successfully – RS Score: 0.87
# ✅ INVH processed successfully – RS Score: 0.86
# ✅ IQV processed successfully – RS Score: 0.54
# ✅ IRM processed successfully – RS Score: 1.07
# ✅ JBHT processed successfully – RS Score: 0.79
# ✅ JBL processed successfully – RS Score: 1.30
# ✅ JKHY processed successfully – RS Score: 0.95
# ✅ J processed successfully – RS Score: 1.00
# ✅ JNJ processed successfully – RS Score: 0.85
# ✅ JCI processed successfully – RS Score: 1.27
# ✅ JPM processed successfully – RS Score: 1.18
# ✅ JNPR processed successfully – RS Score: 0.94
# ✅ K processed successfully – RS Score: 1.18
# ✅ KVUE processed successfully – RS Score: 1.01
# ✅ KDP processed successfully – RS Score: 0.86
# ✅ KEY processed successfully – RS Score: 0.97
# ✅ KEYS processed successfully – RS Score: 0.94
# ✅ KMB processed successfully – RS Score: 0.89
# ✅ KIM processed successfully – RS Score: 0.99
# ✅ KMI processed successfully – RS Score: 1.26
# ✅ KKR processed successfully – RS Score: 1.11
# ✅ KLAC processed successfully – RS Score: 0.97
# ✅ KHC processed successfully – RS Score: 0.68
# ✅ KR processed successfully – RS Score: 1.10
# ✅ LHX processed successfully – RS Score: 0.89
# ✅ LH processed successfully – RS Score: 1.02
# ✅ LRCX processed successfully – RS Score: 0.81
# ✅ LW processed successfully – RS Score: 0.53
# ✅ LVS processed successfully – RS Score: 0.82
# ✅ LDOS processed successfully – RS Score: 0.93
# ✅ LEN processed successfully – RS Score: 0.59
# ✅ LII processed successfully – RS Score: 1.08
# ✅ LLY processed successfully – RS Score: 0.83
# ✅ LIN processed successfully – RS Score: 0.93
# ✅ LYV processed successfully – RS Score: 1.33
# ✅ LKQ processed successfully – RS Score: 0.86
# ✅ LMT processed successfully – RS Score: 0.87
# ✅ L processed successfully – RS Score: 1.02
# ✅ LOW processed successfully – RS Score: 0.89
# ✅ LULU processed successfully – RS Score: 0.84
# ✅ LYB processed successfully – RS Score: 0.53
# ✅ MTB processed successfully – RS Score: 1.09
# ✅ MPC processed successfully – RS Score: 0.84
# ✅ MKTX processed successfully – RS Score: 0.88
# ✅ MAR processed successfully – RS Score: 1.03
# ✅ MMC processed successfully – RS Score: 0.96
# ✅ MLM processed successfully – RS Score: 0.84
# ✅ MAS processed successfully – RS Score: 0.85
# ✅ MA processed successfully – RS Score: 1.12
# ✅ MTCH processed successfully – RS Score: 0.84
# ✅ MKC processed successfully – RS Score: 0.89
# ✅ MCD processed successfully – RS Score: 1.01
# ✅ MCK processed successfully – RS Score: 1.10
# ✅ MDT processed successfully – RS Score: 0.89
# ✅ MRK processed successfully – RS Score: 0.51
# ✅ META processed successfully – RS Score: 1.25
# ✅ MET processed successfully – RS Score: 0.98
# ✅ MTD processed successfully – RS Score: 0.66
# ✅ MGM processed successfully – RS Score: 0.76
# ✅ MCHP processed successfully – RS Score: 0.58
# ✅ MU processed successfully – RS Score: 0.67
# ✅ MSFT processed successfully – RS Score: 0.97
# ✅ MAA processed successfully – RS Score: 1.04
# ✅ MRNA processed successfully – RS Score: 0.16
# ✅ MHK processed successfully – RS Score: 0.80
# ✅ MOH processed successfully – RS Score: 0.81
# ✅ TAP processed successfully – RS Score: 0.87
# ✅ MDLZ processed successfully – RS Score: 0.79
# ✅ MPWR processed successfully – RS Score: 0.91
# ✅ MNST processed successfully – RS Score: 1.01
# ✅ MCO processed successfully – RS Score: 1.05
# ✅ MS processed successfully – RS Score: 1.18
# ✅ MOS processed successfully – RS Score: 0.98
# ✅ MSI processed successfully – RS Score: 1.02
# ✅ MSCI processed successfully – RS Score: 1.02
# ✅ NDAQ processed successfully – RS Score: 1.17
# ✅ NTAP processed successfully – RS Score: 0.82
# ✅ NFLX processed successfully – RS Score: 1.70
# ✅ NEM processed successfully – RS Score: 1.02
# ✅ NWSA processed successfully – RS Score: 0.97
# ✅ NWS processed successfully – RS Score: 1.09
# ✅ NEE processed successfully – RS Score: 0.85
# ✅ NKE processed successfully – RS Score: 0.61
# ✅ NI processed successfully – RS Score: 1.17
# ✅ NDSN processed successfully – RS Score: 0.67
# ✅ NSC processed successfully – RS Score: 0.93
# ✅ NTRS processed successfully – RS Score: 1.12
# ✅ NOC processed successfully – RS Score: 0.87
# ✅ NCLH processed successfully – RS Score: 1.10
# ✅ NRG processed successfully – RS Score: 1.67
# ✅ NUE processed successfully – RS Score: 0.61
# ✅ NVDA processed successfully – RS Score: 1.29
# ✅ NVR processed successfully – RS Score: 0.84
# ✅ NXPI processed successfully – RS Score: 0.71
# ✅ ORLY processed successfully – RS Score: 1.19
# ✅ OXY processed successfully – RS Score: 0.63
# ✅ ODFL processed successfully – RS Score: 0.85
# ✅ OMC processed successfully – RS Score: 0.71
# ✅ ON processed successfully – RS Score: 0.56
# ✅ OKE processed successfully – RS Score: 0.95
# ✅ ORCL processed successfully – RS Score: 1.20
# ✅ OTIS processed successfully – RS Score: 0.89
# ✅ PCAR processed successfully – RS Score: 0.80
# ✅ PKG processed successfully – RS Score: 0.95
# ✅ PLTR processed successfully – RS Score: 5.41
# ✅ PANW processed successfully – RS Score: 1.08
# ✅ PARA processed successfully – RS Score: 0.84
# ✅ PH processed successfully – RS Score: 1.13
# ✅ PAYX processed successfully – RS Score: 1.09
# ✅ PAYC processed successfully – RS Score: 1.28
# ✅ PYPL processed successfully – RS Score: 1.02
# ✅ PNR processed successfully – RS Score: 1.05
# ✅ PEP processed successfully – RS Score: 0.63
# ✅ PFE processed successfully – RS Score: 0.69
# ✅ PCG processed successfully – RS Score: 0.83
# ✅ PM processed successfully – RS Score: 1.47
# ✅ PSX processed successfully – RS Score: 0.77
# ✅ PNW processed successfully – RS Score: 1.02
# ✅ PNC processed successfully – RS Score: 0.99
# ✅ POOL processed successfully – RS Score: 0.75
# ✅ PPG processed successfully – RS Score: 0.75
# ✅ PPL processed successfully – RS Score: 1.02
# ✅ PFG processed successfully – RS Score: 0.87
# ✅ PG processed successfully – RS Score: 0.85
# ✅ PGR processed successfully – RS Score: 1.21
# ✅ PLD processed successfully – RS Score: 0.87
# ✅ PRU processed successfully – RS Score: 0.80
# ✅ PEG processed successfully – RS Score: 0.94
# ✅ PTC processed successfully – RS Score: 0.84
# ✅ PSA processed successfully – RS Score: 0.93
# ✅ PHM processed successfully – RS Score: 0.77
# ✅ PWR processed successfully – RS Score: 1.17
# ✅ QCOM processed successfully – RS Score: 0.71
# ✅ DGX processed successfully – RS Score: 1.09
# ✅ RL processed successfully – RS Score: 1.46
# ✅ RJF processed successfully – RS Score: 1.09
# ✅ RTX processed successfully – RS Score: 1.13
# ✅ O processed successfully – RS Score: 0.89
# ✅ REG processed successfully – RS Score: 1.08
# ✅ REGN processed successfully – RS Score: 0.53
# ✅ RF processed successfully – RS Score: 1.00
# ✅ RSG processed successfully – RS Score: 1.14
# ✅ RMD processed successfully – RS Score: 1.01
# ✅ RVTY processed successfully – RS Score: 0.76
# ✅ ROK processed successfully – RS Score: 1.02
# ✅ ROL processed successfully – RS Score: 1.05
# ✅ ROP processed successfully – RS Score: 0.95
# ✅ ROST processed successfully – RS Score: 1.01
# ✅ RCL processed successfully – RS Score: 1.58
# ✅ SPGI processed successfully – RS Score: 1.05
# ✅ CRM processed successfully – RS Score: 0.92
# ✅ SBAC processed successfully – RS Score: 0.99
# ✅ SLB processed successfully – RS Score: 0.67
# ✅ STX processed successfully – RS Score: 0.96
# ✅ SRE processed successfully – RS Score: 0.87
# ✅ NOW processed successfully – RS Score: 1.22
# ✅ SHW processed successfully – RS Score: 1.01
# ✅ SPG processed successfully – RS Score: 0.98
# ✅ SWKS processed successfully – RS Score: 0.69
# ✅ SJM processed successfully – RS Score: 0.86
# ✅ SW processed successfully – RS Score: 0.91
# ✅ SNA processed successfully – RS Score: 1.06
# ✅ SOLV processed successfully – RS Score: 1.04
# ✅ SO processed successfully – RS Score: 0.96
# ✅ LUV processed successfully – RS Score: 1.01
# ✅ SWK processed successfully – RS Score: 0.72
# ✅ SBUX processed successfully – RS Score: 1.03
# ✅ STT processed successfully – RS Score: 1.13
# ✅ STLD processed successfully – RS Score: 0.89
# ✅ STE processed successfully – RS Score: 0.89
# ✅ SYK processed successfully – RS Score: 1.04
# ✅ SMCI processed successfully – RS Score: 0.45
# ✅ SYF processed successfully – RS Score: 1.26
# ✅ SNPS processed successfully – RS Score: 0.82
# ✅ SYY processed successfully – RS Score: 0.84
# ✅ TMUS processed successfully – RS Score: 1.29
# ✅ TROW processed successfully – RS Score: 0.75
# ✅ TTWO processed successfully – RS Score: 1.41
# ✅ TPR processed successfully – RS Score: 1.76
# ✅ TRGP processed successfully – RS Score: 1.31
# ✅ TGT processed successfully – RS Score: 0.53
# ✅ TEL processed successfully – RS Score: 0.96
# ✅ TDY processed successfully – RS Score: 1.10
# ✅ TER processed successfully – RS Score: 0.58
# ✅ TSLA processed successfully – RS Score: 1.79
# ✅ TXN processed successfully – RS Score: 0.86
# ✅ TPL processed successfully – RS Score: 2.11
# ✅ TXT processed successfully – RS Score: 0.77
# ✅ TMO processed successfully – RS Score: 0.61
# ✅ TJX processed successfully – RS Score: 1.19
# ✅ TKO processed successfully – RS Score: 1.39
# ✅ TSCO processed successfully – RS Score: 0.84
# ✅ TT processed successfully – RS Score: 1.16
# ✅ TDG processed successfully – RS Score: 0.97
# ✅ TRV processed successfully – RS Score: 1.08
# ✅ TRMB processed successfully – RS Score: 1.12
# ✅ TFC processed successfully – RS Score: 0.92
# ✅ TYL processed successfully – RS Score: 1.04
# ✅ TSN processed successfully – RS Score: 0.80
# ✅ USB processed successfully – RS Score: 0.96
# ✅ UBER processed successfully – RS Score: 1.23
# ✅ UDR processed successfully – RS Score: 0.94
# ✅ ULTA processed successfully – RS Score: 0.92
# ✅ UNP processed successfully – RS Score: 0.84
# ✅ UAL processed successfully – RS Score: 1.30
# ✅ UPS processed successfully – RS Score: 0.60
# ✅ URI processed successfully – RS Score: 0.94
# ✅ UNH processed successfully – RS Score: 0.53
# ✅ UHS processed successfully – RS Score: 0.94
# ✅ VLO processed successfully – RS Score: 0.76
# ✅ VTR processed successfully – RS Score: 1.18
# ✅ VLTO processed successfully – RS Score: 0.91
# ✅ VRSN processed successfully – RS Score: 1.45
# ✅ VRSK processed successfully – RS Score: 1.08
# ✅ VZ processed successfully – RS Score: 0.95
# ✅ VRTX processed successfully – RS Score: 0.86
# ✅ VTRS processed successfully – RS Score: 0.69
# ✅ VICI processed successfully – RS Score: 0.92
# ✅ V processed successfully – RS Score: 1.15
# ✅ VST processed successfully – RS Score: 1.49
# ✅ VMC processed successfully – RS Score: 0.92
# ✅ WRB processed successfully – RS Score: 1.23
# ✅ GWW processed successfully – RS Score: 1.02
# ✅ WAB processed successfully – RS Score: 1.10
# ✅ WBA processed successfully – RS Score: 0.55
# ✅ WMT processed successfully – RS Score: 1.36
# ✅ DIS processed successfully – RS Score: 0.98
# ✅ WBD processed successfully – RS Score: 1.01
# ✅ WM processed successfully – RS Score: 0.94
# ✅ WAT processed successfully – RS Score: 0.86
# ✅ WEC processed successfully – RS Score: 1.08
# ✅ WFC processed successfully – RS Score: 1.12
# ✅ WELL processed successfully – RS Score: 1.28
# ✅ WST processed successfully – RS Score: 0.53
# ✅ WDC processed successfully – RS Score: 0.60
# ✅ WY processed successfully – RS Score: 0.75
# ✅ WSM processed successfully – RS Score: 0.99
# ✅ WMB processed successfully – RS Score: 1.28
# ✅ WTW processed successfully – RS Score: 1.06
# ✅ WDAY processed successfully – RS Score: 0.95
# ✅ WYNN processed successfully – RS Score: 0.90
# ✅ XEL processed successfully – RS Score: 1.11
# ✅ XYL processed successfully – RS Score: 0.79
# ✅ YUM processed successfully – RS Score: 0.92
# ✅ ZBRA processed successfully – RS Score: 0.84
# ✅ ZBH processed successfully – RS Score: 0.71
# ✅ ZTS processed successfully – RS Score: 0.80
#
# 📄 461 successfull logged to successfull_tickers.txt
# 📄 42 failed tickers logged to failed_tickers.txt

# %%
# 📌 Variables
tickers = tickers_sp500()
index_name = '^SPY'  # S&P 500 proxy
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()

detailedExportList = pd.DataFrame(columns=['Stock', "RS_Rating", "50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High"])
returns_multiples = []
failed_tickers = []
successful_tickers = []

# 📈 RS Rating Scanner
for symbol in tickers:
    try:
        df = get_finnhub_data(symbol)
        if df.empty or "close" not in df.columns:
            print(f"⚠️ Skipping {symbol}: No data or bad format")
            failed_tickers.append(symbol)
            returns_multiples.append(0)
            continue

        df["close"] = df["close"].astype(float)
        df = df.loc[start_date:end_date]
        df["Percent Change"] = df["close"].pct_change()
        stock_return = (df["Percent Change"] + 1).cumprod().iloc[-1]
        rs_score = stock_return / index_return
        returns_multiples.append(rs_score)
        successful_tickers.append(symbol)
        print(f"✅ {symbol} processed successfully – RS Score: {rs_score:.2f}")
        
    except Exception as e:
        print(f"❌ Error for {symbol}: {e}")
        failed_tickers.append(symbol)
        returns_multiples.append(0)

# 💾 Save tickers and results
pd.DataFrame(tickers, columns=["Ticker"]).to_csv("tickers_sp500.csv", index=False)

with open("failed_tickers.txt", "w") as f:
    f.writelines(f"{t}\n" for t in failed_tickers)

with open("successful_tickers.txt", "w") as f:
    f.writelines(f"{t}\n" for t in successful_tickers)

print(f"\n📄 {len(successful_tickers)} tickers processed successfully.")
print(f"📄 {len(failed_tickers)} failed tickers logged to failed_tickers.txt")

# 📊 Create RS Rating DataFrame
rs_df = pd.DataFrame(list(zip(tickers, returns_multiples)), columns=['Ticker', 'Returns_multiple'])
rs_df['RS_Rating'] = rs_df['Returns_multiple'].rank(pct=True) * 100
rs_df.to_csv("returns_multiples.csv", index=False)

# ✅ Filter top 30% by RS Rating
rs_df = rs_df[rs_df['RS_Rating'] >= rs_df['RS_Rating'].quantile(0.0)]

# ✅ Export all RS-rated stocks without filtering
rs_df.to_csv("rs_full_list.csv", index=False)
print(f"📊 Full RS stock list: {len(rs_df)} saved to rs_full_list.csv")
# Out:
# C:\Users\930140\AppData\Local\Temp\1/ipykernel_32196/397156897.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(html, header=0)[0]
# ✅ MMM processed successfully – RS Score: 1.27
# ✅ AOS processed successfully – RS Score: 0.72
# ✅ ABT processed successfully – RS Score: 1.10
# ✅ ABBV processed successfully – RS Score: 0.97
# ✅ ACN processed successfully – RS Score: 0.94
# ✅ ADBE processed successfully – RS Score: 0.74
# ✅ AMD processed successfully – RS Score: 0.65
# ✅ AES processed successfully – RS Score: 0.53
# ✅ AFL processed successfully – RS Score: 1.07
# ✅ A processed successfully – RS Score: 0.65
# ✅ APD processed successfully – RS Score: 0.95
# ✅ ABNB processed successfully – RS Score: 0.84
# ✅ AKAM processed successfully – RS Score: 0.72
# ✅ ALB processed successfully – RS Score: 0.43
# ✅ ARE processed successfully – RS Score: 0.51
# ✅ ALGN processed successfully – RS Score: 0.62
# ✅ ALLE processed successfully – RS Score: 1.01
# ✅ LNT processed successfully – RS Score: 1.05
# ✅ ALL processed successfully – RS Score: 1.07
# ✅ GOOGL processed successfully – RS Score: 0.85
# ✅ GOOG processed successfully – RS Score: 0.86
# ✅ MO processed successfully – RS Score: 1.10
# ✅ AMZN processed successfully – RS Score: 1.03
# ✅ AMCR processed successfully – RS Score: 0.80
# ✅ AEE processed successfully – RS Score: 1.14
# ✅ AEP processed successfully – RS Score: 0.96
# ✅ AXP processed successfully – RS Score: 1.12
# ✅ AIG processed successfully – RS Score: 0.94
# ✅ AMT processed successfully – RS Score: 0.94
# ✅ AWK processed successfully – RS Score: 0.90
# ✅ AMP processed successfully – RS Score: 1.08
# ✅ AME processed successfully – RS Score: 0.96
# ✅ AMGN processed successfully – RS Score: 0.75
# ✅ APH processed successfully – RS Score: 1.17
# ✅ ADI processed successfully – RS Score: 0.95
# ✅ ANSS processed successfully – RS Score: 0.96
# ✅ AON processed successfully – RS Score: 1.09
# ✅ APA processed successfully – RS Score: 0.54
# ✅ APO processed successfully – RS Score: 1.15
# ✅ AAPL processed successfully – RS Score: 1.01
# ✅ AMAT processed successfully – RS Score: 0.73
# ✅ APTV processed successfully – RS Score: 0.76
# ✅ ACGL processed successfully – RS Score: 0.83
# ✅ ADM processed successfully – RS Score: 0.72
# ✅ ANET processed successfully – RS Score: 1.10
# ✅ AJG processed successfully – RS Score: 1.16
# ✅ AIZ processed successfully – RS Score: 1.01
# ✅ T processed successfully – RS Score: 1.38
# ✅ ATO processed successfully – RS Score: 1.16
# ✅ ADSK processed successfully – RS Score: 1.21
# ✅ ADP processed successfully – RS Score: 1.11
# ✅ AZO processed successfully – RS Score: 1.13
# ✅ AVB processed successfully – RS Score: 0.92
# ✅ AVY processed successfully – RS Score: 0.72
# ✅ AXON processed successfully – RS Score: 2.26
# ✅ BKR processed successfully – RS Score: 1.03
# ✅ BALL processed successfully – RS Score: 0.68
# ✅ BAC processed successfully – RS Score: 1.03
# ✅ BAX processed successfully – RS Score: 0.78
# ✅ BDX processed successfully – RS Score: 0.65
# ✅ BRK.B processed successfully – RS Score: 1.10
# ✅ BBY processed successfully – RS Score: 0.90
# ✅ TECH processed successfully – RS Score: 0.52
# ✅ BIIB processed successfully – RS Score: 0.47
# ✅ BLK processed successfully – RS Score: 1.08
# ✅ BX processed successfully – RS Score: 1.04
# ✅ BK processed successfully – RS Score: 1.35
# ✅ BA processed successfully – RS Score: 1.01
# ✅ BKNG processed successfully – RS Score: 1.26
# ✅ BSX processed successfully – RS Score: 1.24
# ✅ BMY processed successfully – RS Score: 0.90
# ✅ AVGO processed successfully – RS Score: 1.48
# ✅ BR processed successfully – RS Score: 1.05
# ✅ BRO processed successfully – RS Score: 1.09
# ✅ BF.B processed successfully – RS Score: 0.64
# ✅ BLDR processed successfully – RS Score: 0.65
# ✅ BG processed successfully – RS Score: 0.71
# ✅ BXP processed successfully – RS Score: 0.93
# ✅ CHRW processed successfully – RS Score: 1.06
# ✅ CDNS processed successfully – RS Score: 0.99
# ✅ CZR processed successfully – RS Score: 0.78
# ✅ CPT processed successfully – RS Score: 0.98
# ✅ CPB processed successfully – RS Score: 0.66
# ✅ COF processed successfully – RS Score: 1.26
# ✅ CAH processed successfully – RS Score: 1.35
# ✅ KMX processed successfully – RS Score: 0.84
# ✅ CCL processed successfully – RS Score: 1.39
# ✅ CARR processed successfully – RS Score: 1.02
# ✅ CAT processed successfully – RS Score: 0.90
# ✅ CBOE processed successfully – RS Score: 1.06
# ✅ CBRE processed successfully – RS Score: 1.26
# ✅ CDW processed successfully – RS Score: 0.76
# ✅ COR processed successfully – RS Score: 1.13
# ✅ CNC processed successfully – RS Score: 0.69
# ✅ CNP processed successfully – RS Score: 1.10
# ✅ CF processed successfully – RS Score: 1.00
# ✅ CRL processed successfully – RS Score: 0.56
# ✅ SCHW processed successfully – RS Score: 1.00
# ✅ CHTR processed successfully – RS Score: 1.34
# ✅ CVX processed successfully – RS Score: 0.79
# ✅ CMG processed successfully – RS Score: 0.75
# ✅ CB processed successfully – RS Score: 0.96
# ✅ CHD processed successfully – RS Score: 0.79
# ✅ CI processed successfully – RS Score: 0.80
# ✅ CINF processed successfully – RS Score: 1.11
# ✅ CTAS processed successfully – RS Score: 1.11
# ✅ CSCO processed successfully – RS Score: 1.14
# ✅ C processed successfully – RS Score: 1.06
# ✅ CFG processed successfully – RS Score: 1.02
# ✅ CLX processed successfully – RS Score: 0.88
# ✅ CME processed successfully – RS Score: 1.13
# ✅ CMS processed successfully – RS Score: 0.98
# ✅ KO processed successfully – RS Score: 0.98
# ✅ CTSH processed successfully – RS Score: 1.03
# ✅ CL processed successfully – RS Score: 0.83
# ✅ CMCSA processed successfully – RS Score: 0.79
# ✅ CAG processed successfully – RS Score: 0.65
# ✅ COP processed successfully – RS Score: 0.70
# ✅ ED processed successfully – RS Score: 0.92
# ✅ STZ processed successfully – RS Score: 0.66
# ✅ CEG processed successfully – RS Score: 1.20
# ✅ COO processed successfully – RS Score: 0.74
# ✅ CPRT processed successfully – RS Score: 1.03
# ✅ GLW processed successfully – RS Score: 1.20
# ✅ CPAY processed successfully – RS Score: 1.12
# ✅ CTVA processed successfully – RS Score: 1.09
# ✅ CSGP processed successfully – RS Score: 0.77
# ✅ COST processed successfully – RS Score: 1.12
# ✅ CTRA processed successfully – RS Score: 0.80
# ✅ CRWD processed successfully – RS Score: 1.16
# ✅ CCI processed successfully – RS Score: 0.85
# ✅ CSX processed successfully – RS Score: 0.82
# ✅ CMI processed successfully – RS Score: 1.04
# ✅ CVS processed successfully – RS Score: 0.94
# ✅ DHR processed successfully – RS Score: 0.64
# ✅ DRI processed successfully – RS Score: 1.23
# ✅ DVA processed successfully – RS Score: 0.92
# ✅ DAY processed successfully – RS Score: 0.85
# ✅ DECK processed successfully – RS Score: 0.78
# ✅ DE processed successfully – RS Score: 1.13
# ✅ DELL processed successfully – RS Score: 0.68
# ✅ DAL processed successfully – RS Score: 0.87
# ✅ DVN processed successfully – RS Score: 0.62
# ✅ DXCM processed successfully – RS Score: 0.59
# ✅ FANG processed successfully – RS Score: 0.67
# ✅ DLR processed successfully – RS Score: 1.03
# ✅ DFS processed successfully – RS Score: 1.44
# ✅ DG processed successfully – RS Score: 0.54
# ✅ DLTR processed successfully – RS Score: 0.64
# ✅ D processed successfully – RS Score: 0.91
# ✅ DPZ processed successfully – RS Score: 0.85
# ✅ DASH processed successfully – RS Score: 1.52
# ✅ DOV processed successfully – RS Score: 0.90
# ✅ DOW processed successfully – RS Score: 0.46
# ✅ DHI processed successfully – RS Score: 0.73
# ✅ DTE processed successfully – RS Score: 1.02
# ✅ DUK processed successfully – RS Score: 0.98
# ✅ DD processed successfully – RS Score: 0.79
# ✅ EMN processed successfully – RS Score: 0.73
# ✅ ETN processed successfully – RS Score: 0.90
# ✅ EBAY processed successfully – RS Score: 1.18
# ✅ ECL processed successfully – RS Score: 0.97
# ✅ EIX processed successfully – RS Score: 0.67
# ✅ EW processed successfully – RS Score: 0.77
# ✅ EA processed successfully – RS Score: 1.03
# ✅ ELV processed successfully – RS Score: 0.62
# ✅ EMR processed successfully – RS Score: 0.97
# ✅ ENPH processed successfully – RS Score: 0.37
# ✅ ETR processed successfully – RS Score: 1.28
# ✅ EOG processed successfully – RS Score: 0.81
# ✅ EPAM processed successfully – RS Score: 0.88
# ✅ EQT processed successfully – RS Score: 1.25
# ✅ EFX processed successfully – RS Score: 0.98
# ✅ EQIX processed successfully – RS Score: 0.97
# ✅ EQR processed successfully – RS Score: 0.93
# ✅ ERIE processed successfully – RS Score: 0.82
# ✅ ESS processed successfully – RS Score: 0.95
# ✅ EL processed successfully – RS Score: 0.42
# ✅ EG processed successfully – RS Score: 0.79
# ✅ EVRG processed successfully – RS Score: 1.04
# ✅ ES processed successfully – RS Score: 0.90
# ✅ EXC processed successfully – RS Score: 0.98
# ✅ EXE processed successfully – RS Score: 1.22
# ✅ EXPE processed successfully – RS Score: 1.34
# ✅ EXPD processed successfully – RS Score: 0.87
# ✅ EXR processed successfully – RS Score: 0.87
# ✅ XOM processed successfully – RS Score: 0.83
# ✅ FFIV processed successfully – RS Score: 1.46
# ✅ FDS processed successfully – RS Score: 0.93
# ✅ FICO processed successfully – RS Score: 1.36
# ✅ FAST processed successfully – RS Score: 1.08
# ✅ FRT processed successfully – RS Score: 0.84
# ✅ FDX processed successfully – RS Score: 0.81
# ✅ FIS processed successfully – RS Score: 0.91
# ✅ FITB processed successfully – RS Score: 0.92
# ✅ FSLR processed successfully – RS Score: 0.89
# ✅ FE processed successfully – RS Score: 0.92
# ✅ FI processed successfully – RS Score: 1.12
# ✅ F processed successfully – RS Score: 0.77
# ✅ FTNT processed successfully – RS Score: 1.52
# ✅ FTV processed successfully – RS Score: 0.85
# ✅ FOXA processed successfully – RS Score: 1.50
# ✅ FOX processed successfully – RS Score: 1.50
# ✅ BEN processed successfully – RS Score: 0.82
# ✅ FCX processed successfully – RS Score: 0.68
# ✅ GRMN processed successfully – RS Score: 1.06
# ✅ IT processed successfully – RS Score: 0.90
# ✅ GE processed successfully – RS Score: 1.25
# ✅ GEHC processed successfully – RS Score: 0.81
# ✅ GEV processed successfully – RS Score: 2.34
# ✅ GEN processed successfully – RS Score: 1.01
# ✅ GNRC processed successfully – RS Score: 0.81
# ✅ GD processed successfully – RS Score: 0.82
# ✅ GIS processed successfully – RS Score: 0.67
# ✅ GM processed successfully – RS Score: 0.99
# ✅ GPC processed successfully – RS Score: 0.73
# ✅ GILD processed successfully – RS Score: 1.30
# ✅ GPN processed successfully – RS Score: 0.68
# ✅ GL processed successfully – RS Score: 1.28
# ✅ GDDY processed successfully – RS Score: 1.25
# ✅ GS processed successfully – RS Score: 1.18
# ✅ HAL processed successfully – RS Score: 0.51
# ✅ HIG processed successfully – RS Score: 1.11
# ✅ HAS processed successfully – RS Score: 0.99
# ✅ HCA processed successfully – RS Score: 1.02
# ✅ DOC processed successfully – RS Score: 0.76
# ✅ HSIC processed successfully – RS Score: 0.85
# ✅ HSY processed successfully – RS Score: 0.70
# ✅ HES processed successfully – RS Score: 0.78
# ✅ HPE processed successfully – RS Score: 0.90
# ✅ HLT processed successfully – RS Score: 1.11
# ✅ HOLX processed successfully – RS Score: 0.66
# ✅ HD processed successfully – RS Score: 0.98
# ✅ HON processed successfully – RS Score: 0.95
# ✅ HRL processed successfully – RS Score: 0.73
# ✅ HST processed successfully – RS Score: 0.74
# ✅ HWM processed successfully – RS Score: 1.74
# ✅ HPQ processed successfully – RS Score: 0.83
# ✅ HUBB processed successfully – RS Score: 0.89
# ✅ HUM processed successfully – RS Score: 0.58
# ✅ HBAN processed successfully – RS Score: 1.02
# ✅ HII processed successfully – RS Score: 0.78
# ✅ IBM processed successfully – RS Score: 1.37
# ✅ IEX processed successfully – RS Score: 0.76
# ✅ IDXX processed successfully – RS Score: 0.85
# ✅ ITW processed successfully – RS Score: 0.88
# ✅ INCY processed successfully – RS Score: 0.97
# ✅ IR processed successfully – RS Score: 0.82
# ✅ PODD processed successfully – RS Score: 1.56
# ✅ INTC processed successfully – RS Score: 0.60
# ✅ ICE processed successfully – RS Score: 1.13
# ✅ IFF processed successfully – RS Score: 0.69
# ✅ IP processed successfully – RS Score: 1.12
# ✅ IPG processed successfully – RS Score: 0.71
# ✅ INTU processed successfully – RS Score: 0.90
# ✅ ISRG processed successfully – RS Score: 1.28
# ✅ IVZ processed successfully – RS Score: 0.87
# ✅ INVH processed successfully – RS Score: 0.86
# ✅ IQV processed successfully – RS Score: 0.54
# ✅ IRM processed successfully – RS Score: 1.07
# ✅ JBHT processed successfully – RS Score: 0.79
# ✅ JBL processed successfully – RS Score: 1.30
# ✅ JKHY processed successfully – RS Score: 0.95
# ✅ J processed successfully – RS Score: 1.00
# ✅ JNJ processed successfully – RS Score: 0.85
# ✅ JCI processed successfully – RS Score: 1.27
# ✅ JPM processed successfully – RS Score: 1.18
# ✅ JNPR processed successfully – RS Score: 0.94
# ✅ K processed successfully – RS Score: 1.18
# ✅ KVUE processed successfully – RS Score: 1.01
# ✅ KDP processed successfully – RS Score: 0.86
# ✅ KEY processed successfully – RS Score: 0.97
# ✅ KEYS processed successfully – RS Score: 0.94
# ✅ KMB processed successfully – RS Score: 0.89
# ✅ KIM processed successfully – RS Score: 0.99
# ✅ KMI processed successfully – RS Score: 1.26
# ✅ KKR processed successfully – RS Score: 1.11
# ✅ KLAC processed successfully – RS Score: 0.97
# ✅ KHC processed successfully – RS Score: 0.68
# ✅ KR processed successfully – RS Score: 1.10
# ✅ LHX processed successfully – RS Score: 0.89
# ✅ LH processed successfully – RS Score: 1.02
# ✅ LRCX processed successfully – RS Score: 0.81
# ✅ LW processed successfully – RS Score: 0.53
# ✅ LVS processed successfully – RS Score: 0.82
# ✅ LDOS processed successfully – RS Score: 0.93
# ✅ LEN processed successfully – RS Score: 0.59
# ✅ LII processed successfully – RS Score: 1.08
# ✅ LLY processed successfully – RS Score: 0.83
# ✅ LIN processed successfully – RS Score: 0.93
# ✅ LYV processed successfully – RS Score: 1.33
# ✅ LKQ processed successfully – RS Score: 0.86
# ✅ LMT processed successfully – RS Score: 0.87
# ✅ L processed successfully – RS Score: 1.02
# ✅ LOW processed successfully – RS Score: 0.89
# ✅ LULU processed successfully – RS Score: 0.84
# ✅ LYB processed successfully – RS Score: 0.53
# ✅ MTB processed successfully – RS Score: 1.09
# ✅ MPC processed successfully – RS Score: 0.84
# ✅ MKTX processed successfully – RS Score: 0.88
# ✅ MAR processed successfully – RS Score: 1.03
# ✅ MMC processed successfully – RS Score: 0.96
# ✅ MLM processed successfully – RS Score: 0.84
# ✅ MAS processed successfully – RS Score: 0.85
# ✅ MA processed successfully – RS Score: 1.12
# ✅ MTCH processed successfully – RS Score: 0.84
# ✅ MKC processed successfully – RS Score: 0.89
# ✅ MCD processed successfully – RS Score: 1.01
# ✅ MCK processed successfully – RS Score: 1.10
# ✅ MDT processed successfully – RS Score: 0.89
# ✅ MRK processed successfully – RS Score: 0.51
# ✅ META processed successfully – RS Score: 1.25
# ✅ MET processed successfully – RS Score: 0.98
# ✅ MTD processed successfully – RS Score: 0.66
# ✅ MGM processed successfully – RS Score: 0.76
# ✅ MCHP processed successfully – RS Score: 0.58
# ✅ MU processed successfully – RS Score: 0.67
# ✅ MSFT processed successfully – RS Score: 0.97
# ✅ MAA processed successfully – RS Score: 1.04
# ✅ MRNA processed successfully – RS Score: 0.16
# ✅ MHK processed successfully – RS Score: 0.80
# ✅ MOH processed successfully – RS Score: 0.81
# ✅ TAP processed successfully – RS Score: 0.87
# ✅ MDLZ processed successfully – RS Score: 0.79
# ✅ MPWR processed successfully – RS Score: 0.91
# ✅ MNST processed successfully – RS Score: 1.01
# ✅ MCO processed successfully – RS Score: 1.05
# ✅ MS processed successfully – RS Score: 1.18
# ✅ MOS processed successfully – RS Score: 0.98
# ✅ MSI processed successfully – RS Score: 1.02
# ✅ MSCI processed successfully – RS Score: 1.02
# ✅ NDAQ processed successfully – RS Score: 1.17
# ✅ NTAP processed successfully – RS Score: 0.82
# ✅ NFLX processed successfully – RS Score: 1.70
# ✅ NEM processed successfully – RS Score: 1.02
# ✅ NWSA processed successfully – RS Score: 0.97
# ✅ NWS processed successfully – RS Score: 1.09
# ✅ NEE processed successfully – RS Score: 0.85
# ✅ NKE processed successfully – RS Score: 0.61
# ✅ NI processed successfully – RS Score: 1.17
# ✅ NDSN processed successfully – RS Score: 0.67
# ✅ NSC processed successfully – RS Score: 0.93
# ✅ NTRS processed successfully – RS Score: 1.12
# ✅ NOC processed successfully – RS Score: 0.87
# ✅ NCLH processed successfully – RS Score: 1.10
# ✅ NRG processed successfully – RS Score: 1.67
# ✅ NUE processed successfully – RS Score: 0.61
# ✅ NVDA processed successfully – RS Score: 1.29
# ✅ NVR processed successfully – RS Score: 0.84
# ✅ NXPI processed successfully – RS Score: 0.71
# ✅ ORLY processed successfully – RS Score: 1.19
# ✅ OXY processed successfully – RS Score: 0.63
# ✅ ODFL processed successfully – RS Score: 0.85
# ✅ OMC processed successfully – RS Score: 0.71
# ✅ ON processed successfully – RS Score: 0.56
# ✅ OKE processed successfully – RS Score: 0.95
# ✅ ORCL processed successfully – RS Score: 1.20
# ✅ OTIS processed successfully – RS Score: 0.89
# ✅ PCAR processed successfully – RS Score: 0.80
# ✅ PKG processed successfully – RS Score: 0.95
# ✅ PLTR processed successfully – RS Score: 5.41
# ✅ PANW processed successfully – RS Score: 1.08
# ✅ PARA processed successfully – RS Score: 0.84
# ✅ PH processed successfully – RS Score: 1.13
# ✅ PAYX processed successfully – RS Score: 1.09
# ✅ PAYC processed successfully – RS Score: 1.28
# ✅ PYPL processed successfully – RS Score: 1.02
# ✅ PNR processed successfully – RS Score: 1.05
# ✅ PEP processed successfully – RS Score: 0.63
# ✅ PFE processed successfully – RS Score: 0.69
# ✅ PCG processed successfully – RS Score: 0.83
# ✅ PM processed successfully – RS Score: 1.47
# ✅ PSX processed successfully – RS Score: 0.77
# ✅ PNW processed successfully – RS Score: 1.02
# ✅ PNC processed successfully – RS Score: 0.99
# ✅ POOL processed successfully – RS Score: 0.75
# ✅ PPG processed successfully – RS Score: 0.75
# ✅ PPL processed successfully – RS Score: 1.02
# ✅ PFG processed successfully – RS Score: 0.87
# ✅ PG processed successfully – RS Score: 0.85
# ✅ PGR processed successfully – RS Score: 1.21
# ✅ PLD processed successfully – RS Score: 0.87
# ✅ PRU processed successfully – RS Score: 0.80
# ✅ PEG processed successfully – RS Score: 0.94
# ✅ PTC processed successfully – RS Score: 0.84
# ✅ PSA processed successfully – RS Score: 0.93
# ✅ PHM processed successfully – RS Score: 0.77
# ✅ PWR processed successfully – RS Score: 1.17
# ✅ QCOM processed successfully – RS Score: 0.71
# ✅ DGX processed successfully – RS Score: 1.09
# ✅ RL processed successfully – RS Score: 1.46
# ✅ RJF processed successfully – RS Score: 1.09
# ✅ RTX processed successfully – RS Score: 1.13
# ✅ O processed successfully – RS Score: 0.89
# ✅ REG processed successfully – RS Score: 1.08
# ✅ REGN processed successfully – RS Score: 0.53
# ✅ RF processed successfully – RS Score: 1.00
# ✅ RSG processed successfully – RS Score: 1.14
# ✅ RMD processed successfully – RS Score: 1.01
# ✅ RVTY processed successfully – RS Score: 0.76
# ✅ ROK processed successfully – RS Score: 1.02
# ✅ ROL processed successfully – RS Score: 1.05
# ✅ ROP processed successfully – RS Score: 0.95
# ✅ ROST processed successfully – RS Score: 1.01
# ✅ RCL processed successfully – RS Score: 1.58
# ✅ SPGI processed successfully – RS Score: 1.05
# ✅ CRM processed successfully – RS Score: 0.92
# ✅ SBAC processed successfully – RS Score: 0.99
# ✅ SLB processed successfully – RS Score: 0.67
# ✅ STX processed successfully – RS Score: 0.96
# ✅ SRE processed successfully – RS Score: 0.87
# ✅ NOW processed successfully – RS Score: 1.22
# ✅ SHW processed successfully – RS Score: 1.01
# ✅ SPG processed successfully – RS Score: 0.98
# ✅ SWKS processed successfully – RS Score: 0.69
# ✅ SJM processed successfully – RS Score: 0.86
# ✅ SW processed successfully – RS Score: 0.91
# ✅ SNA processed successfully – RS Score: 1.06
# ✅ SOLV processed successfully – RS Score: 1.04
# ✅ SO processed successfully – RS Score: 0.96
# ✅ LUV processed successfully – RS Score: 1.01
# ✅ SWK processed successfully – RS Score: 0.72
# ✅ SBUX processed successfully – RS Score: 1.03
# ✅ STT processed successfully – RS Score: 1.13
# ✅ STLD processed successfully – RS Score: 0.89
# ✅ STE processed successfully – RS Score: 0.89
# ✅ SYK processed successfully – RS Score: 1.04
# ✅ SMCI processed successfully – RS Score: 0.45
# ✅ SYF processed successfully – RS Score: 1.26
# ✅ SNPS processed successfully – RS Score: 0.82
# ✅ SYY processed successfully – RS Score: 0.84
# ✅ TMUS processed successfully – RS Score: 1.29
# ✅ TROW processed successfully – RS Score: 0.75
# ✅ TTWO processed successfully – RS Score: 1.41
# ✅ TPR processed successfully – RS Score: 1.76
# ✅ TRGP processed successfully – RS Score: 1.31
# ✅ TGT processed successfully – RS Score: 0.53
# ✅ TEL processed successfully – RS Score: 0.96
# ✅ TDY processed successfully – RS Score: 1.10
# ✅ TER processed successfully – RS Score: 0.58
# ✅ TSLA processed successfully – RS Score: 1.79
# ✅ TXN processed successfully – RS Score: 0.86
# ✅ TPL processed successfully – RS Score: 2.11
# ✅ TXT processed successfully – RS Score: 0.77
# ✅ TMO processed successfully – RS Score: 0.61
# ✅ TJX processed successfully – RS Score: 1.19
# ✅ TKO processed successfully – RS Score: 1.39
# ✅ TSCO processed successfully – RS Score: 0.84
# ✅ TT processed successfully – RS Score: 1.16
# ✅ TDG processed successfully – RS Score: 0.97
# ✅ TRV processed successfully – RS Score: 1.08
# ✅ TRMB processed successfully – RS Score: 1.12
# ✅ TFC processed successfully – RS Score: 0.92
# ✅ TYL processed successfully – RS Score: 1.04
# ✅ TSN processed successfully – RS Score: 0.80
# ✅ USB processed successfully – RS Score: 0.96
# ✅ UBER processed successfully – RS Score: 1.23
# ✅ UDR processed successfully – RS Score: 0.94
# ✅ ULTA processed successfully – RS Score: 0.92
# ✅ UNP processed successfully – RS Score: 0.84
# ✅ UAL processed successfully – RS Score: 1.30
# ✅ UPS processed successfully – RS Score: 0.60
# ✅ URI processed successfully – RS Score: 0.94
# ✅ UNH processed successfully – RS Score: 0.53
# ✅ UHS processed successfully – RS Score: 0.94
# ✅ VLO processed successfully – RS Score: 0.76
# ✅ VTR processed successfully – RS Score: 1.18
# ✅ VLTO processed successfully – RS Score: 0.91
# ✅ VRSN processed successfully – RS Score: 1.45
# ✅ VRSK processed successfully – RS Score: 1.08
# ✅ VZ processed successfully – RS Score: 0.95
# ✅ VRTX processed successfully – RS Score: 0.86
# ✅ VTRS processed successfully – RS Score: 0.69
# ✅ VICI processed successfully – RS Score: 0.92
# ✅ V processed successfully – RS Score: 1.15
# ✅ VST processed successfully – RS Score: 1.49
# ✅ VMC processed successfully – RS Score: 0.92
# ✅ WRB processed successfully – RS Score: 1.23
# ✅ GWW processed successfully – RS Score: 1.02
# ✅ WAB processed successfully – RS Score: 1.10
# ✅ WBA processed successfully – RS Score: 0.55
# ✅ WMT processed successfully – RS Score: 1.36
# ✅ DIS processed successfully – RS Score: 0.98
# ✅ WBD processed successfully – RS Score: 1.01
# ✅ WM processed successfully – RS Score: 0.94
# ✅ WAT processed successfully – RS Score: 0.86
# ✅ WEC processed successfully – RS Score: 1.08
# ✅ WFC processed successfully – RS Score: 1.12
# ✅ WELL processed successfully – RS Score: 1.28
# ✅ WST processed successfully – RS Score: 0.53
# ✅ WDC processed successfully – RS Score: 0.60
# ✅ WY processed successfully – RS Score: 0.75
# ✅ WSM processed successfully – RS Score: 0.99
# ✅ WMB processed successfully – RS Score: 1.28
# ✅ WTW processed successfully – RS Score: 1.06
# ✅ WDAY processed successfully – RS Score: 0.95
# ✅ WYNN processed successfully – RS Score: 0.90
# ✅ XEL processed successfully – RS Score: 1.11
# ✅ XYL processed successfully – RS Score: 0.79
# ✅ YUM processed successfully – RS Score: 0.92
# ✅ ZBRA processed successfully – RS Score: 0.84
# ✅ ZBH processed successfully – RS Score: 0.71
# ✅ ZTS processed successfully – RS Score: 0.80
#
# 📄 503 tickers processed successfully.
# 📄 0 failed tickers logged to failed_tickers.txt
# 📊 Full RS stock list: 503 saved to rs_full_list.csv

# %%
# Checking Minervini conditions of all stocks in given list (DYNAMIC)
# Initialize export list
detailedExportList = pd.DataFrame(columns=[
    'Stock', "RS_Rating", "50 Day MA", "150 Day Ma", "200 Day MA", 
    "52 Week Low", "52 week High"
])

# ✅ Use only the top 30% RS stocks
rs_stocks = rs_df['Ticker']

for stock in rs_stocks:
    try:
        # Fetch data from Finnhub
        df = get_finnhub_data(stock, from_days=500)
        if df.empty:
            raise ValueError("No data returned")

        # Clean and prep columns
        df.columns = [col.split(". ")[-1] for col in df.columns]
        df["close"] = df["close"].astype(float)
        df["high"] = df["high"].astype(float)
        df["low"] = df["low"].astype(float)

        # Compute SMAs
        df["SMA_50"] = df["close"].rolling(window=50).mean()
        df["SMA_150"] = df["close"].rolling(window=150).mean()
        df["SMA_200"] = df["close"].rolling(window=200).mean()

        # Grab latest values
        currentClose = df["close"].iloc[-1]
        moving_average_50 = df["SMA_50"].iloc[-1]
        moving_average_150 = df["SMA_150"].iloc[-1]
        moving_average_200 = df["SMA_200"].iloc[-1]
        
        # Check for missing SMA values
        # Check for missing SMA values
        if pd.isnull([moving_average_50, moving_average_150, moving_average_200]).any():
            print(f"📉 Data too short for {stock}: {len(df)} rows")
            status_msg = (f"❌ Skipping {stock}: Missing SMA values - "
                          f"SMA_50: {moving_average_50}, "
                          f"SMA_150: {moving_average_150}, "
                          f"SMA_200: {moving_average_200}")
    
            detailedExportList = pd.concat([detailedExportList, pd.DataFrame([{
                'Stock': stock, 
                "RS_Rating": RS_Rating,
                "50 Day MA": moving_average_50, 
                "150 Day Ma": moving_average_150, 
                "200 Day MA": moving_average_200, 
                "52 Week Low": low_of_52week, 
                "52 week High": high_of_52week,
                "Status": status_msg
            }])], ignore_index=True)

            print(status_msg)
            continue
         
        low_of_52week = round(df["low"].iloc[-260:].min(), 2)
        high_of_52week = round(df["high"].iloc[-260:].max(), 2)
        RS_Rating = round(rs_df[rs_df['Ticker'] == stock].RS_Rating.iloc[0])

        try:
            moving_average_200_20 = df["SMA_200"].iloc[-20]
        except Exception:
            moving_average_200_20 = 0

        # ✅ Minervini Conditions
        condition_1 = currentClose > moving_average_150 > moving_average_200
        condition_2 = moving_average_150 > moving_average_200
        condition_3 = moving_average_200 > moving_average_200_20
        condition_4 = moving_average_50 > moving_average_150 > moving_average_200
        condition_5 = currentClose > moving_average_50
        condition_6 = currentClose >= (1.3 * low_of_52week)
        condition_7 = currentClose >= (0.75 * high_of_52week)

        if not all([condition_1, condition_2, condition_3, condition_4, condition_5, condition_6, condition_7]):
            failed_conds = [
                f"1" if not condition_1 else "",
                f"2" if not condition_2 else "",
                f"3" if not condition_3 else "",
                f"4" if not condition_4 else "",
                f"5" if not condition_5 else "",
                f"6" if not condition_6 else "",
                f"7" if not condition_7 else "",
            ]
            reason = f"❌ Failed Minervini conditions: {', '.join(filter(None, failed_conds))}"
            
            detailedExportList = pd.concat([detailedExportList, pd.DataFrame([{
                'Stock': stock, 
                "RS_Rating": RS_Rating,
                "50 Day MA": moving_average_50, 
                "150 Day Ma": moving_average_150, 
                "200 Day MA": moving_average_200, 
                "52 Week Low": low_of_52week, 
                "52 week High": high_of_52week,
                "Status": reason
            }])], ignore_index=True)
            print(reason)

            print(f"✅ {stock} made the Minervini requirements")

    except Exception as e:
        print(f"⚠️ Could not process {stock}: {e}")

# ✅ Split the results
passed_df = detailedExportList[detailedExportList["Status"] == "✅ Passed Minervini"]
failed_df = detailedExportList[detailedExportList["Status"] != "✅ Passed Minervini"]

# 📤 Export each to a separate Excel file
passed_df.to_excel("Minervini_Passed.xlsx", index=False)
failed_df.to_excel("Minervini_Failed.xlsx", index=False)
# Out:
# C:\Users\930140\AppData\Local\Temp\1/ipykernel_32196/1393253152.py:88: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   detailedExportList = pd.concat([detailedExportList, pd.DataFrame([{
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ AOS made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ ABT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ ABBV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ ACN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ ADBE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ AMD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ AES made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ AFL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ A made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ APD made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ ABNB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ AKAM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ ALB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ ARE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ ALGN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ ALLE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ LNT made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ ALL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ GOOGL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ GOOG made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ MO made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ AMZN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ AMCR made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ AEE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ AEP made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ AXP made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ AIG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ AMT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ AWK made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ AMP made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4, 6
# ✅ AME made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ AMGN made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ APH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ ADI made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ ANSS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ AON made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ APA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ APO made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ AAPL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ AMAT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ APTV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ ACGL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ ADM made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4, 7
# ✅ ANET made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ AJG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ AIZ made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ T made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ ATO made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ ADSK made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ ADP made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ AZO made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ AVB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ AVY made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ AXON made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ BKR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ BALL made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ BAC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ BAX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ BDX made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ BRK.B made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ BBY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ TECH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ BIIB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ BLK made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6, 7
# ✅ BX made the Minervini requirements
# ❌ Failed Minervini conditions: 3
# ✅ BA made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ BKNG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6, 7
# ✅ BMY made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ AVGO made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ BR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5
# ✅ BRO made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ BF.B made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ BLDR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ BG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ BXP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ CHRW made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ CDNS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ CZR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ CPT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ CPB made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ COF made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ KMX made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ CCL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4
# ✅ CARR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4
# ✅ CAT made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ CBOE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ CBRE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ CDW made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ COR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ CNC made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ CF made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 7
# ✅ CRL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 5, 6
# ✅ CVX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ CMG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ CB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 5, 6
# ✅ CHD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ CI made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ CINF made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ CTAS made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ CSCO made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ C made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ CFG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ CLX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ CMS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ KO made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ CTSH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ CL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ CMCSA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ CAG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ COP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ ED made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ STZ made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ CEG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ COO made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ CPRT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ GLW made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ CPAY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ CSGP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 5, 6
# ✅ CTRA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ CCI made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ CSX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ CMI made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ CVS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ DHR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ DVA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6, 7
# ✅ DAY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 7
# ✅ DECK made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4, 7
# ✅ DELL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 7
# ✅ DAL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ DVN made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4, 7
# ✅ DXCM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ FANG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ DLR made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ DFS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ DG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ DLTR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ D made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ DPZ made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ DOV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ DOW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ DHI made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ DTE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ DUK made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ DD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ EMN made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ ETN made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ ECL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ EIX made the Minervini requirements
# ❌ Failed Minervini conditions: 3
# ✅ EW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ EA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ ELV made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ EMR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ ENPH made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ ETR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ EOG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 7
# ✅ EPAM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4
# ✅ EFX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ EQIX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ EQR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ ERIE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ ESS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ EL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ EG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ EVRG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ ES made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ EXC made the Minervini requirements
# 📉 Data too short for EXE: 154 rows
# ❌ Skipping EXE: Missing SMA values - SMA_50: 105.8442, SMA_150: 100.16590000000001, SMA_200: nan
# ❌ Failed Minervini conditions: 1, 4
# ✅ EXPE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ EXPD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ EXR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ XOM made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ FDS made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ FICO made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ FRT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ FDX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ FIS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ FITB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ FSLR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ FE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ FI made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ F made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ FTV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ BEN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ FCX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5
# ✅ GRMN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ IT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ GEHC made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ GEN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6, 7
# ✅ GNRC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ GD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ GIS made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4, 6
# ✅ GM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ GPC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5
# ✅ GILD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ GPN made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ GL made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ GDDY made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ GS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ HAL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4
# ✅ HAS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ HCA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ DOC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ HSIC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ HSY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 5, 6
# ✅ HES made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 7
# ✅ HPE made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ HLT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ HOLX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ HD made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4, 6
# ✅ HON made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ HRL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ HST made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ HPQ made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ HUBB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ HUM made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ HBAN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ HII made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ IEX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ IDXX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ ITW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 5, 6, 7
# ✅ INCY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ IR made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ PODD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6, 7
# ✅ INTC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ IFF made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ IP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ IPG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ INTU made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ ISRG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4
# ✅ IVZ made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ INVH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ IQV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ IRM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ JBHT made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ JBL made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ JKHY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ J made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ JNJ made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ JPM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ JNPR made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ K made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ KVUE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ KDP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4
# ✅ KEY made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ KEYS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ KMB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ KIM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ KKR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ KLAC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ KHC made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ KR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ LHX made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ LH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ LRCX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 5, 6, 7
# ✅ LW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 7
# ✅ LVS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ LDOS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ LEN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ LII made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ LLY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ LIN made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ LYV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ LKQ made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ LMT made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ L made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ LOW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 7
# ✅ LULU made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ LYB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ MTB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ MPC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6, 7
# ✅ MKTX made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ MAR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ MMC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ MLM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ MAS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ MTCH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ MKC made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ MCD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ MDT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ MRK made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ META made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ MET made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ MTD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ MGM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ MCHP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ MU made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ MSFT made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ MAA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ MRNA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ MHK made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ MOH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ TAP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ MDLZ made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ MPWR made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ MCO made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ MS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4
# ✅ MOS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ MSI made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ MSCI made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ NDAQ made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ NTAP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5
# ✅ NEM made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4, 6
# ✅ NWSA made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ NWS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ NEE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ NKE made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ NI made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ NDSN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ NSC made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ NTRS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ NOC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 7
# ✅ NCLH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ NUE made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ NVDA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ NVR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ NXPI made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ ORLY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ OXY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ ODFL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ OMC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ ON made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6, 7
# ✅ OKE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ ORCL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 5, 6
# ✅ OTIS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 5, 6
# ✅ PCAR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ PKG made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ PANW made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ PARA made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ PH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ PYPL made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ PNR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ PEP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ PFE made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ PCG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ PSX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ PNW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ PNC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ POOL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ PPG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ PPL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ PFG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ PG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ PLD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ PRU made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ PEG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ PTC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ PSA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ PHM made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ PWR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ QCOM made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ DGX made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ RL made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ RJF made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ O made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ REG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ REGN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ RF made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ RSG made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ RMD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ RVTY made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ ROK made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ ROL made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ ROP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ ROST made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ RCL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ SPGI made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ CRM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ SBAC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ SLB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ STX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ SRE made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ NOW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ SHW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ SPG made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ SWKS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ SJM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ SW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 6
# ✅ SNA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4
# ✅ SOLV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ SO made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ LUV made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ SWK made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6, 7
# ✅ SBUX made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ STT made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ STLD made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 6
# ✅ STE made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ SYK made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ SMCI made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ SYF made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ SNPS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ SYY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5
# ✅ TMUS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ TROW made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5
# ✅ TRGP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ TGT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ TEL made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ TDY made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6, 7
# ✅ TER made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 7
# ✅ TSLA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ TXN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ TXT made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ TMO made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 5, 6
# ✅ TSCO made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ TT made the Minervini requirements
# ❌ Failed Minervini conditions: 6
# ✅ TDG made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ TRMB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ TFC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ TYL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ TSN made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 3, 4, 6
# ✅ USB made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ UDR made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ ULTA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ UNP made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 7
# ✅ UAL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ UPS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ URI made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ UNH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ UHS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4
# ✅ VLO made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5
# ✅ VTR made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ VLTO made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ VZ made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ VRTX made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ VTRS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 4, 5, 6
# ✅ VICI made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ VST made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ VMC made the Minervini requirements
# ❌ Failed Minervini conditions: 4, 6
# ✅ GWW made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ WAB made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 7
# ✅ WBA made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ WMT made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ DIS made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 7
# ✅ WBD made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ WM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 4, 5, 6
# ✅ WAT made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ WEC made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ WFC made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ WELL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6, 7
# ✅ WST made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ WDC made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ WY made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ WSM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 5, 6
# ✅ WTW made the Minervini requirements
# ❌ Failed Minervini conditions: 4
# ✅ WDAY made the Minervini requirements
# ❌ Failed Minervini conditions: 3, 4
# ✅ WYNN made the Minervini requirements
# ❌ Failed Minervini conditions: 5
# ✅ XEL made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 6
# ✅ XYL made the Minervini requirements
# ❌ Failed Minervini conditions: 5, 6
# ✅ YUM made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 7
# ✅ ZBRA made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ ZBH made the Minervini requirements
# ❌ Failed Minervini conditions: 1, 2, 3, 4, 5, 6
# ✅ ZTS made the Minervini requirements
